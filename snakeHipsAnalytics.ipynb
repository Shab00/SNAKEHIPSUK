# %% [markdown]
# # ***Machine learnig Using the SnakeHipsUK Youtube Channel***

# %% [markdown]
# This notebook demonstrates the use of Google API for data retrieval, date parsing with `dateutil`, and text processing with `nltk`. It includes visualizations using `seaborn` and `matplotlib`, and generates word clouds to visualize text data. Additionally, it outlines steps for cleaning the data and creating features for further analysis.

# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
hips = pd.read_csv('/content/drive/MyDrive/snakeHipsAnal/snakeHips.csv')

# %% [markdown]
# ## Dataset Description
#
# The dataset contains information about various videos from the Snakehips YouTube channel. The columns in the dataset include:
#
# - `video_id`: Unique identifier for the video.
# - `channelTitle`: Title of the YouTube channel.
# - `title`: Title of the video.
# - `description`: Description of the video.
# - `tags`: Tags associated with the video.
# - `publishedAt`: Date and time when the video was published.
# - `viewCount`: Number of views the video has received.
# - `likeCount`: Number of likes the video has received.
# - `favouriteCount`: Number of times the video has been favorited.
# - `commentCount`: Number of comments on the video.
# - `duration`: Duration of the video.
# - `definition`: Video quality (e.g., HD, SD).
# - `caption`: Whether the video has captions.
# - `pushblishDayName`: Day of the week when the video was published.
# - `tagCount`: Number of tags associated with the video.
#
# ## Data Cleaning and Feature Creation
#
# 1. **Data Cleaning**:
#    - Handle missing values in columns such as `likeCount`, `favouriteCount`, and `commentCount`.
#    - Convert `publishedAt` to a datetime format for easier manipulation.
#    - Normalize text data by removing special characters and converting text to lowercase.
#
# 2. **Feature Creation**:
#    - Extract additional features from the `publishedAt` column, such as the year, month, and day of the week.
#    - Calculate the length of the video title and description.
#    - Count the number of tags associated with each video.
#    - Generate word clouds to visualize the most common words in video titles and descriptions.
#
# By following these steps, we aim to gain insights into the characteristics of popular videos and understand the factors that contribute to their success.

# %%
hips
# Out:
#         video_id channelTitle  \
# 0    lMeaksVlPN4    Snakehips
# 1    JHFhuS3pGXE    Snakehips
# 2    Bq8tAdgP2HU    Snakehips
# 3    hPe44LLzmGM    Snakehips
# 4    WjCBiRCSLqw    Snakehips
# ..           ...          ...
# 123  scREqUpkLw4    Snakehips
# 124  HfQaebOEkAU    Snakehips
# 125  IUukUEfiqyU    Snakehips
# 126  dUxbX4VXp6Y    Snakehips
# 127  AtYCK4O4ZbE    Snakehips
#
#                                                  title  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER. (...
# 3    Snakehips & EARTHGANG (SNAKEGANG) feat Sinéad ...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) (O...
# ..                                                 ...
# 123               Banks - Warm Water (SNAKEHIPS Remix)
# 124          The Weeknd - Wanderlust (SNAKEHIPS Remix)
# 125                          SNAKEHIPS - Miss U Always
# 126                                SNAKEHIPS - Make It
# 127  SNAKEHIPS - On & On (ft George Maple) OFFICIAL...
#
#                                            description  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER.\n...
# 3    Snakehips & EARTHGANG feat Sinéad Harnett - Be...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) \n...
# ..                                                 ...
# 123  »Follow Snakehips:\nSoundcloud: https://soundc...
# 124  »Follow Snakehips:\nSoundcloud: https://soundc...
# 125  »Follow Snakehips:\nSoundcloud: https://soundc...
# 126  »Follow Snakehips:\nhttps://soundcloud.com/sna...
# 127  »PREORDER LIMITED 12INCH 'ON&ON' VINYL HERE: h...
#
#                                                   tags  \
# 0    ['snakehips majestic casual snake hips hip hop...
# 1    ['snakehips majestic casual snake hips hip hop...
# 2    ['snakehips majestic casual snake hips hip hop...
# 3    ['snakehips majestic casual snake hips hip hop...
# 4    ['snakehips majestic casual snake hips hip hop...
# ..                                                 ...
# 123  ['snakehips', 'majestic casual', 'forever', 's...
# 124  ['snakehips', 'majestic casual', 'snake', 'hip...
# 125  ['snakehips', 'majestic casual', 'snake', 'hip...
# 126  ['snakehips', 'majestic casual', 'snake', 'hip...
# 127  ['snakehips', 'on and on', 'majestic', 'noisey...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  \
# 0    2024-07-25 19:17:16+00:00     4983.0      212.0             NaN
# 1    2024-07-22 17:20:17+00:00     7341.0      339.0             NaN
# 2    2024-07-19 16:00:08+00:00   341304.0     2112.0             NaN
# 3    2024-06-23 08:54:29+00:00   163764.0     3121.0             NaN
# 4    2023-12-13 12:57:52+00:00   154845.0      321.0             NaN
# ..                         ...        ...        ...             ...
# 123  2014-06-18 14:46:32+00:00    15605.0      261.0             NaN
# 124  2014-06-18 11:33:18+00:00   838720.0     8766.0             NaN
# 125  2014-06-17 16:43:37+00:00    47582.0      593.0             NaN
# 126  2014-06-17 11:34:41+00:00    49497.0      462.0             NaN
# 127  2013-05-03 11:38:32+00:00   289976.0     4055.0             NaN
#
#      commentCount duration definition  caption pushblishDayName  tagCount
# 0             7.0  PT3M18S         hd    False         Thursday        13
# 1             9.0  PT3M42S         hd    False           Monday        13
# 2            53.0  PT2M56S         hd    False           Friday        13
# 3            32.0  PT3M10S         hd    False           Sunday        21
# 4             7.0  PT3M30S         hd    False        Wednesday        13
# ..            ...      ...        ...      ...              ...       ...
# 123           4.0  PT2M45S         sd    False        Wednesday        21
# 124          62.0  PT3M41S         sd    False        Wednesday        21
# 125          11.0  PT2M36S         sd    False          Tuesday        18
# 126          10.0  PT3M42S         sd    False          Tuesday        18
# 127         173.0  PT3M19S         hd    False           Friday        23
#
# [128 rows x 15 columns]

# %%
hips.dtypes
# Out:
# video_id             object
# channelTitle         object
# title                object
# description          object
# tags                 object
# publishedAt          object
# viewCount           float64
# likeCount           float64
# favouriteCount      float64
# commentCount        float64
# duration             object
# definition           object
# caption                bool
# pushblishDayName     object
# tagCount              int64
# dtype: object

# %%
hips.isnull().sum()
hips.dropna()
# Out:
# Empty DataFrame
# Columns: [video_id, channelTitle, title, description, tags, publishedAt, viewCount, likeCount, favouriteCount, commentCount, duration, definition, caption, pushblishDayName, tagCount]
# Index: []

# %%
for column in ['favouriteCount', 'definition', 'caption', 'tags']:
  print(f"Unique values for {column}:")
  print(hips[column].unique())
  print("-" * 20)
# Out:
# Unique values for favouriteCount:
# [nan]
# --------------------
# Unique values for definition:
# ['hd' 'sd']
# --------------------
# Unique values for caption:
# [False  True]
# --------------------
# Unique values for tags:
# ["['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'earthgang', 'sinead harnett', 'dance', 'hip hop', 'rappers', 'rap', 'snakegang', 'block party']"
#  nan
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'Helix', 'Helix Records', 'Payday Records', 'Dance', 'Techno', 'Tech House', 'HR', 'Future Bass', 'EDM', 'Dance EDM', 'Snakehips', 'Water', 'WATER', 'WATER.', 'Snakehips Water', 'Brcye Vine', 'Vine', 'Bryce', 'Snake', 'Hips', 'Snakehips - WATER. feat. Bryce Vine']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'duckwrth']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'Helix Records', 'Helix', 'WATER', 'Snakehips', 'Snake', 'Hips', 'WATER.', 'Snakehips Water', 'Water Snakehips']"
#  '[\'snakehips\', \'snakehips lie for you\', \'snakehips jess glynne\', \'oh i wanna lie for you\', \'lie for you lyrics\', \'jess glynne 2020\', \'snakehips 2020\', \'davido 2020\', \'a boogie wit da hoodie 2020\', \'snakehips davido\', \'snakehips a boogie wit da hoodie\', \'jess glynne lie for you\', \'davido lie for you\', \'a boogie wit da hoodie lie for you\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips on and on\', \'snakehips forever\', \'snakehips either way\', \'snakehips cruel\', \'jess\']'
#  '[\'snakehips\', \'snakehips lie for you\', \'snakehips jess glynne\', \'oh wanna lie for you\', \'lie for you lyrics\', \'jess glynne 2020\', \'snakehips 2020\', \'davido 2020\', \'boogie wit da hoodie 2020\', \'snakehips davido\', \'snakehips boogie wit da hoodie\', \'jess glynne lie for you\', \'davido lie for you\', \'boogie wit da hoodie lie for you\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips on and on\', \'snakehips forever\', \'snakehips either way\', \'snakehips cruel\', \'jess\']'
#  '[\'snakehips\', \'snakehips troyboi\', \'snakehips troyboi wavez\', \'snakehips wavez\', \'snakehips got the wave\', \'i got the wave\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips on and on\', \'snakehips forever\', \'snakehips either way\', \'snakehips cruel\', \'snakehips remix\', \'snakehips all my friends lyrics\', \'snakehips gold\', \'snakehips all my friends remix\', \'snakehips falling\', \'snakehips summer fade\', \'snakehips on and on kaytranada\', \'snakehips wanderlust\', \'troyboi\']'
#  '[\'snakehips\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips either way\', \'snakehips forever\', \'snakehips cruel\', \'snakehips on and on\', \'snakehips remix\', \'snakehips summer fade\', \'snakehips falling\', \'snakehips gold\', \'snakehips anna of the north\', \'snakehips channel tres remix\', \'snakehips summer fade channel tres remix\', \'channel tres\', \'channel tres top down\', \'channel tres black moses\', \'channel tres controller\', \'channel tres live\', \'channel tres jet black\']'
#  '[\'snakehips\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips forever\', \'snakehips either way\', \'snakehips on and on\', \'snakehips cruel\', \'snakehips remix\', \'snakehips gucci rocknrolla\', \'snakehips all my friends lyrics\', \'snakehips gold\', \'snakehips summer fade\', \'snakehips summer fade lyrics\', \'snakehips anna of the north summer fade\', \'snakehips anna of the north\', \'anna of the north\', \'anna of the north summer fade\', \'anna of the north snakehips\', \'anna\']'
#  "['Gucci Rock Rolla (Freejak Remix) [Audio]', 'Hoffman West', 'Pop', 'Snakehips feat. Rivers Cuomo KYLE']"
#  "['Gucci Rock Rolla (Banx Ranx Remix) [Audio]', 'Hoffman West', 'Pop', 'Snakehips feat. Rivers Cuomo KYLE']"
#  '[\'snakehips\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips either way\', \'snakehips forever\', \'snakehips cruel\', \'snakehips on and on\', \'snakehips remix\', \'snakehips all my friends lyrics\', \'snakehips cruzin\', \'snakehips gold\', \'snakehips kyle\', \'snakehips rivers cuomo\', \'snakehips rivers cuomo kyle\', \'snakehips gucci rock n rolla\', \'gucci rock n rolla\', \'gucci rock and roller\', \'snakehips gucci rock and roller\', \'snakehips rivers cuomo kyle gucci rock n rolla\']'
#  '[\'snakehips\', "snakehips cruzin\'", \'snakehips stay home tapes\', \'snakehips for the of it\', \'snakehips jeremih\', \'snakehips amine\', \'snakehips for the f^_^k of it\', \'snakehips for the fuck of it\', \'snakehips deja vu\', \'snakehips knox brown\', \'snakehips chaz french\', \'snakehips knox brown chaz french deja vu\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips either way\', \'snakehips cruel\', \'snakehips forever\', \'snakehips remix\', \'snakehips on and on\', \'snakehips live\']'
#  '[\'snakehips\', \'snakehips all my friends\', \'snakehips either way\', "snakehips don\'t leave", \'snakehips cruel\', \'snakehips forever\', \'snakehips remix\', \'snakehips on and on\', \'snakehips dimelo\', \'snakehips live\', \'snakehips all my friends lyrics\', \'snakehips 2018\', \'snakehips new single\', \'snakehips new album\', \'snakehips new song\', \'snakehips stay home tapes\', \'snakehips act\', \'snakehips for the of it\', \'snakehips for the f^_^k of it\', \'snakehips jeremih amine\']'
#  '[\'snakehips\', \'snakehips all my friends\', "snakehips don\'t leave", \'snakehips either way\', \'snakehips cruel\', \'snakehips forever\', \'snakehips remix\', \'snakehips on and on\', \'snakehips dimelo\', \'snakehips live\', \'snakehips all my friends remix\', \'st rules church monifieth\', \'crash st.rules\', \'snakehips new music\', \'snakehips new single\', \'snakehips new song\', \'snakehips new album\', \'snakehips 2018\', \'snakehips stay home tapes\', "Cruzin\' (Stay Home Tapes Act 1)", \'Snakehips\', \'feat.\']'
#  "['Either Way', 'Hoffman West', 'Pop', 'Snakehips & Anne-Marie feat. Joey Bada$$']"
#  "['snakehips', 'sam smith', 'too good at goodbyes', 'remix']"
#  "['beats', 'snakehips', 'summer', 'bummer', 'lana del rey', 'remix']"
#  "['Either Way', 'Hoffman West', 'Rap/Hip-Hop', 'Snakehips & Anne-Marie feat. Joey Bada$$']"
#  "['snakehips', 'dram', 'elhae', 'her', 'd.r.a.m.', 'h.e.r.', 'snakehips mo', 'snakehips right now', 'right now', 'snakehips dont leave', 'snakehips cruel', 'snakehips all my friends', 'snakehips zayn', 'snakehips zayn malik', 'snakehips live', 'snakehips acoustic', 'snakehips dj', 'snakehips festival', 'new snakehips', 'snakehips song', 'Hoffman West', 'Pop', 'Right Now', 'Snakehips feat. ELHAE', 'D.R.A.M. H.E.R.']"
#  '["Don\'t Leave", \'Hoffman West\', \'Pop\', \'Snakehips & MØ\']'
#  "['snakehips', 'dont leave', 'snakehips dont leave', 'mo dont leave', 'mo snakehips dont leave', 'mo snakehips dont leave live', 'mo snakehips dont leave acoustic', 'mo snakehips dont leave official video', 'mo snakehips dont leave lyric video', 'mo snakehips dont leave audio', 'mo snakehips dont leave cover', 'mo snakehips dont leave lyrics', 'snake hips', 'snake hips dont leave', 'snake hips mo', 'Danish singer', 'snakehips cruel', 'snakehips zayn', 'snakehips Tinashe', 'chance']"
#  "['Snakehips', 'Snakehipsvevo', 'snakehips', 'Snake Hips', 'dont leave', 'snakehips dont leave', 'vevo', 'mo dont leave', 'official', 'mo snakehips dont leave', 'video', 'mo snakehips dont leave live', 'music video', 'mo snakehips dont leave acoustic', 'mo snakehips dont leave official video', 'single', 'album', 'mo snakehips dont leave lyric video', 'and MO', 'mo snakehips dont leave audio', 'Dont Leave', 'mo snakehips dont leave cover', 'All My Friends', 'dont', 'leave']"
#  "['Snakehips', 'snakehips', 'Snakehipsvevo', 'cruel official video', 'Snake Hips', 'cruel lyrics', 'snakehips cruel', 'vevo', 'official', 'zayn', 'cruel zayn', 'video', 'music video', 'zayn cruel', 'zayn malik cruel', 'single', 'snakehips and zayn', 'album', 'snakehips ft zayn', 'featuring ZAYN', 'zayn ft snakehips', 'ZAYN', 'cruel snakehips', 'Cruel', 'xruel snakehips and zayn', 'dance', 'snakehips all my friends', 'all my friends', 'electronic', 'days are gone snakehips', 'days are gone', 'money on me']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'zayn', '1d', 'one direction', 'snakehips', 'music', 'all my friends', 'tinashe']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'dimelo', 'tory lanez', 'snakehips dimelo', 'snakehips tory lanez']"
#  '[\'Snakehips All My Friends\', \'Snakehips\\xa0remix\', \'All My Friends official video\', \'All My Friends\\xa0official audio\', \'All My Friends\\xa0lyrics\', \'All My Friends\\xa0Live\', \'Snakehips full album\', \'Snakehips official audio\', \'Snakehips\\xa0official video\', \'Snakehips lyrics\', \'Snakehips live\', \'Forever\', \'Either Way\', "Don\'t Leave", \'Cruel\', \'Tinashe\', \'Tinashe All My Friends\', \'Chance the Rapper\', \'Chance the Rapper All My Friends\', \'TikTok\', \'TikTok All My Friends\', \'All My Friends\', \'Hoffman West\']'
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'snakehips all my friends', 'snakehips forever', 'snakehips all my friends lyrics', 'snakehips remix', 'snakehips gone', 'snakehips all my friends remix', 'snakehips days with you', 'snakehips on and on', 'snakehips forever part 2', 'snakehips live']"
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'remix', '99 souls', 'all my friends', 'all my friends remix', 'tinashe', 'chance the rapper', 'snakehips all my friends', 'forever', 'part 2']"
#  '[\'Snakehips All My Friends\', \'Snakehips\\xa0remix\', \'All My Friends official video\', \'All My Friends\\xa0official audio\', \'All My Friends\\xa0lyrics\', \'All My Friends\\xa0Live\', \'Snakehips full album\', \'Snakehips official audio\', \'Snakehips\\xa0official video\', \'Snakehips lyrics\', \'Snakehips live\', \'Forever\', \'Either Way\', "Don\'t Leave", \'Cruel\', \'Tinashe\', \'Tinashe All My Friends\', \'Chance the Rapper\', \'Chance the Rapper All My Friends\', \'TikTok\', \'TikTok All My Friends\', \'All My Friends\', \'Electronica\', \'The\']'
#  "['snakehips majestic casual snake hips hip hop block party soul Snakehips', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'tinashe', 'chance the rapper', 'all my friends', 'music', 'Pop Music (Musical Genre)', 'days with you', 'jess glynne', 'Snakehips feat. Tinashe & Chance the Rapper', 'Chance the Rapper', 'All My Friends official', 'Snakehips official video', 'Snakehips remix', 'Tinashe live', 'Snakehips live', 'Snakehips all my friends', 'forever']"
#  "['snakehips forever', 'snakehips', 'Electronica', 'Forever (Pt. II)', 'Hoffman West', 'Snakehips feat. Kaleem Taylor']"
#  "['Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'hip hop', 'block party', 'snakehips', 'snakehipsuk', 'majestic casual', 'snake', 'hips', 'thesoundyouneed', 'sinead harnett', 'sinead', 'harnett']"
#  "['snakehips', 'majestic casual', 'forever', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'Snakehips', 'Forever', 'Summer', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine']"
#  "['snakehips', 'majestic casual', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'Remix (Industry)', 'Forever', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk']"
#  "['snakehips', 'majestic casual', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk']"
#  "['snakehips', 'majestic casual', 'forever', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'Snakehips', 'Summer', 'Chilled', 'Soulful', 'House', 'Beats', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine', 'BANKS (Musical Artist)', 'Remix (Industry)']"
#  "['snakehips', 'majestic casual', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'The Weeknd (Musical Artist)', 'Wanderlust (Canonical Version)', 'Music (TV Genre)', 'Remix (Industry)', 'Snakehips', 'Summer', 'Soulful', 'House', 'Beats', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine']"
#  "['snakehips', 'majestic casual', 'snake', 'hips', 'hip hop', 'block party', 'soul', 'Snakehips', 'Summer', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine']"
#  "['snakehips', 'on and on', 'majestic', 'noisey', 'pitchfork', 'george maple', 'sun', 'beach', 'bliss', 'fader', 'earmilk', 'hype machine', 'Snakehips', 'Summer', 'Soulful', 'House', 'Beats', 'Majestic', 'Noisey', 'Pitchfork', 'Fader', 'Earmilk', 'Hype machine']"]
# --------------------

# %%
# !pip install isodate==0.6.1
# Out:
# Requirement already satisfied: isodate==0.6.1 in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate==0.6.1) (1.16.0)

# %%
import isodate

# %% [markdown]
# ## Data Processing Steps
#
# In this section, we perform several data processing steps to prepare the dataset for analysis. These steps include converting video durations to seconds and timestamps for publication dates.
#
# ### Converting Video Duration to Seconds
#
# We convert the video duration from ISO 8601 format to seconds. This involves parsing the duration and then converting it to total seconds:

# %%
hips['durationSecs'] = hips['duration'].apply(lambda x: isodate.parse_duration(x))

# %%
hips['duration_seconds'] = hips['durationSecs'].dt.total_seconds()

# %% [markdown]
# Parsing Duration: The isodate.parse_duration function is used to parse the ISO 8601 duration format into a timedelta object.
# Converting to Seconds: The dt.total_seconds() method converts the timedelta object to total seconds, making it easier to analyze and compare video durations.

# %% [markdown]
# Converting Published Date to Timestamp
# We convert the publishedAt column to a datetime format and then to a Unix timestamp:

# %%
hips['publishedAt'] = pd.to_datetime(hips['publishedAt'])
hips['publishedAt_timestamp'] = hips['publishedAt'].apply(lambda x: x.timestamp())

# %% [markdown]
# Datetime Conversion: The pd.to_datetime function converts the publishedAt column to a pandas datetime object.
# Timestamp Conversion: The timestamp() method is applied to convert the datetime object to a Unix timestamp, which represents the number of seconds since January 1, 1970.
# These transformations standardize the duration and publication date formats, facilitating further analysis and visualization.

# %% [markdown]
# ### Data Cleaning: Removing Dollar Signs
#
# In this step, we remove any dollar signs (`$`) from the data to avoid issues when creating plots. Dollar signs can interfere with numerical operations and visualizations, so it's important to clean them from the dataset:

# %%
hips = hips.replace('\$', '', regex=True)

# %% [markdown]
# Removing Dollar Signs: The replace method with a regular expression (regex=True) is used to find and remove all occurrences of the dollar sign ($) in the dataset. This ensures that the data is clean and ready for numerical analysis and plotting.

# %%
hips
# Out:
#         video_id channelTitle  \
# 0    lMeaksVlPN4    Snakehips
# 1    JHFhuS3pGXE    Snakehips
# 2    Bq8tAdgP2HU    Snakehips
# 3    hPe44LLzmGM    Snakehips
# 4    WjCBiRCSLqw    Snakehips
# ..           ...          ...
# 123  scREqUpkLw4    Snakehips
# 124  HfQaebOEkAU    Snakehips
# 125  IUukUEfiqyU    Snakehips
# 126  dUxbX4VXp6Y    Snakehips
# 127  AtYCK4O4ZbE    Snakehips
#
#                                                  title  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER. (...
# 3    Snakehips & EARTHGANG (SNAKEGANG) feat Sinéad ...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) (O...
# ..                                                 ...
# 123               Banks - Warm Water (SNAKEHIPS Remix)
# 124          The Weeknd - Wanderlust (SNAKEHIPS Remix)
# 125                          SNAKEHIPS - Miss U Always
# 126                                SNAKEHIPS - Make It
# 127  SNAKEHIPS - On & On (ft George Maple) OFFICIAL...
#
#                                            description  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER.\n...
# 3    Snakehips & EARTHGANG feat Sinéad Harnett - Be...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) \n...
# ..                                                 ...
# 123  »Follow Snakehips:\nSoundcloud: https://soundc...
# 124  »Follow Snakehips:\nSoundcloud: https://soundc...
# 125  »Follow Snakehips:\nSoundcloud: https://soundc...
# 126  »Follow Snakehips:\nhttps://soundcloud.com/sna...
# 127  »PREORDER LIMITED 12INCH 'ON&ON' VINYL HERE: h...
#
#                                                   tags  \
# 0    ['snakehips majestic casual snake hips hip hop...
# 1    ['snakehips majestic casual snake hips hip hop...
# 2    ['snakehips majestic casual snake hips hip hop...
# 3    ['snakehips majestic casual snake hips hip hop...
# 4    ['snakehips majestic casual snake hips hip hop...
# ..                                                 ...
# 123  ['snakehips', 'majestic casual', 'forever', 's...
# 124  ['snakehips', 'majestic casual', 'snake', 'hip...
# 125  ['snakehips', 'majestic casual', 'snake', 'hip...
# 126  ['snakehips', 'majestic casual', 'snake', 'hip...
# 127  ['snakehips', 'on and on', 'majestic', 'noisey...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-07-25 19:17:16+00:00     4983.0      212.0             NaN
# 1   2024-07-22 17:20:17+00:00     7341.0      339.0             NaN
# 2   2024-07-19 16:00:08+00:00   341304.0     2112.0             NaN
# 3   2024-06-23 08:54:29+00:00   163764.0     3121.0             NaN
# 4   2023-12-13 12:57:52+00:00   154845.0      321.0             NaN
# ..                        ...        ...        ...             ...
# 123 2014-06-18 14:46:32+00:00    15605.0      261.0             NaN
# 124 2014-06-18 11:33:18+00:00   838720.0     8766.0             NaN
# 125 2014-06-17 16:43:37+00:00    47582.0      593.0             NaN
# 126 2014-06-17 11:34:41+00:00    49497.0      462.0             NaN
# 127 2013-05-03 11:38:32+00:00   289976.0     4055.0             NaN
#
#      commentCount duration definition  caption pushblishDayName  tagCount  \
# 0             7.0  PT3M18S         hd    False         Thursday        13
# 1             9.0  PT3M42S         hd    False           Monday        13
# 2            53.0  PT2M56S         hd    False           Friday        13
# 3            32.0  PT3M10S         hd    False           Sunday        21
# 4             7.0  PT3M30S         hd    False        Wednesday        13
# ..            ...      ...        ...      ...              ...       ...
# 123           4.0  PT2M45S         sd    False        Wednesday        21
# 124          62.0  PT3M41S         sd    False        Wednesday        21
# 125          11.0  PT2M36S         sd    False          Tuesday        18
# 126          10.0  PT3M42S         sd    False          Tuesday        18
# 127         173.0  PT3M19S         hd    False           Friday        23
#
#        durationSecs  duration_seconds  publishedAt_timestamp
# 0   0 days 00:03:18             198.0           1.721935e+09
# 1   0 days 00:03:42             222.0           1.721669e+09
# 2   0 days 00:02:56             176.0           1.721405e+09
# 3   0 days 00:03:10             190.0           1.719133e+09
# 4   0 days 00:03:30             210.0           1.702472e+09
# ..              ...               ...                    ...
# 123 0 days 00:02:45             165.0           1.403103e+09
# 124 0 days 00:03:41             221.0           1.403091e+09
# 125 0 days 00:02:36             156.0           1.403023e+09
# 126 0 days 00:03:42             222.0           1.403005e+09
# 127 0 days 00:03:19             199.0           1.367581e+09
#
# [128 rows x 18 columns]

# %% [markdown]
# ### Sorting and Visualizing Top 5 Videos by View Count
#
# In this step, we sort the dataset by the `viewCount` column in descending order and visualize the top 5 videos with the highest view counts using a bar chart.

# %%
hips_sorted = hips.sort_values('viewCount', ascending=False)

top_5 = hips_sorted.head(5)

plt.figure(figsize=(10, 6))
plt.bar(top_5['title'], top_5['viewCount'])
plt.xlabel('Video Title')
plt.ylabel('View Count')
plt.title('Top 5 Videos by View Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Sorting: We sort the dataset by the viewCount column in descending order using the sort_values method.
# Selecting Top 5: We select the top 5 videos with the highest view counts using the head method.
# Bar Chart Visualization: We create a bar chart to visualize the view counts of the top 5 videos. The plt.bar function is used to create the bar chart, and plt.xticks is used to rotate the x-axis labels for better readability. The plt.tight_layout function ensures that the layout is adjusted to fit all elements properly.
# This step helps in identifying the most popular videos based on view count and provides a clear visual representation of their popularity.

# %% [markdown]
# ### Aggregating and Visualizing Total View Count by Day of the Week
#
# In this step, we aggregate the total view counts by the day of the week and visualize the results using a bar chart.

# %%
total_views = hips.groupby('pushblishDayName')['viewCount'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.bar(total_views['pushblishDayName'], total_views['viewCount'])
plt.xlabel('Day of the Week')
plt.ylabel('Total View Count')
plt.title('Total View Count by Day of the Week')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Aggregation: We use the groupby method to group the dataset by the pushblishDayName column and calculate the total view counts for each day using the sum method. The reset_index method is used to convert the result back to a DataFrame.
# Bar Chart Visualization: We create a bar chart to visualize the total view counts for each day of the week. The plt.bar function is used to create the bar chart, and plt.xticks is used to rotate the x-axis labels for better readability. The plt.tight_layout function ensures that the layout is adjusted to fit all elements properly.
# This step helps in understanding the distribution of total view counts across different days of the week, providing insights into which days are most popular for video views.

# %% [markdown]
# ### Time Series Analysis of Video Views
#
# In this step, we convert the `publishedAt_timestamp` to a date format, aggregate the total view counts by date, and visualize the results using a time series plot.

# %%
hips['date'] = pd.to_datetime(hips['publishedAt_timestamp'], unit='s').dt.date
daily_views = hips.groupby('date')['viewCount'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(daily_views['date'], daily_views['viewCount'])
plt.xlabel('Date')
plt.ylabel('Total View Count')
plt.title('Time Series of Video Views')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Timestamp to Date Conversion: We convert the publishedAt_timestamp column from a timestamp to a date format using pd.to_datetime and extract the date part with .dt.date.
# Aggregation: We group the dataset by the date column and calculate the total view counts for each date using the sum method. The reset_index method is used to convert the result back to a DataFrame.
# Time Series Plot: We create a time series plot to visualize the total view counts over time. The plt.plot function is used to create the line plot, and plt.xticks is used to rotate the x-axis labels for better readability. The plt.tight_layout function ensures that the layout is adjusted to fit all elements properly.
# This step helps in understanding the trend of video views over time, providing insights into how view counts change on a daily basis.

# %% [markdown]
# ### Distribution of Video Durations
#
# In this step, we visualize the distribution of video durations using a histogram. This helps in understanding the spread and frequency of different video lengths in the dataset.

# %%
plt.figure(figsize=(10, 6))
plt.hist(hips['duration_seconds'], bins=20)
plt.xlabel('Video Duration (seconds)')
plt.ylabel('Frequency')
plt.title('Distribution of Video Durations')
plt.show()

# %% [markdown]
# Histogram Visualization: We create a histogram to visualize the distribution of video durations. The plt.hist function is used to create the histogram, with bins=20 specifying the number of bins for the histogram.
# Figure Size: The plt.figure(figsize=(10, 6)) function sets the size of the figure to 10 inches by 6 inches.
# Labels and Title: We add labels for the x-axis (Video Duration (seconds)) and y-axis (Frequency), and set the title of the plot to Distribution of Video Durations.
# This step helps in understanding the distribution of video lengths in the dataset, providing insights into the common durations of videos.

# %% [markdown]
# ### Text Preprocessing and Word Cloud Visualization
#
# In this step, we preprocess the text data from the `title`, `description`, and `tags` columns, and visualize the most frequent words using a word cloud.

# %%
from wordcloud import WordCloud
import re

text = " ".join(hips['title'].astype(str).tolist() + hips['description'].astype(str).tolist() + hips['tags'].astype(str).tolist())


text = text.lower()
text = re.sub(r'[^\w\s]', '', text)
stop_words = set(stopwords.words('english'))
words = word_tokenize(text)
words = [word for word in words if not word in stop_words]
text = " ".join(words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Combine Text Data: We combine the text data from the title, description, and tags columns into a single string.
# Text Preprocessing:
# Convert the text to lowercase using text.lower().
# Remove punctuation using re.sub(r'[^\w\s]', '', text).
# Remove stopwords using the stopwords list from the nltk library and tokenize the text using word_tokenize.
# Word Cloud Generation: We generate a word cloud using the WordCloud class from the wordcloud library, specifying the width, height, and background color.
# Visualization: We plot the word cloud using plt.imshow and remove the axis using plt.axis("off").
# This step helps in visualizing the most frequent words in the text data, providing insights into the common themes and topics.

# %% [markdown]
# ### One-Hot Encoding Categorical Columns
#
# In this step, we perform one-hot encoding on the `caption` and `definition` columns. One-hot encoding is a process that converts categorical variables into a format that can be provided to machine learning algorithms to improve predictions.

# %%
hips = pd.get_dummies(hips, columns=['caption', 'definition'])

# %% [markdown]
# One-Hot Encoding: The pd.get_dummies function is used to convert the caption and definition columns into binary (0 or 1) columns. This transformation allows the machine learning model to interpret these categorical variables effectively.
# Result: New columns are created for each unique value in the caption and definition columns. For example, caption_False, caption_True, definition_hd, and definition_sd.

# %%
hips
# Out:
#         video_id channelTitle  \
# 0    lMeaksVlPN4    Snakehips
# 1    JHFhuS3pGXE    Snakehips
# 2    Bq8tAdgP2HU    Snakehips
# 3    hPe44LLzmGM    Snakehips
# 4    WjCBiRCSLqw    Snakehips
# ..           ...          ...
# 123  scREqUpkLw4    Snakehips
# 124  HfQaebOEkAU    Snakehips
# 125  IUukUEfiqyU    Snakehips
# 126  dUxbX4VXp6Y    Snakehips
# 127  AtYCK4O4ZbE    Snakehips
#
#                                                  title  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER. (...
# 3    Snakehips & EARTHGANG (SNAKEGANG) feat Sinéad ...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) (O...
# ..                                                 ...
# 123               Banks - Warm Water (SNAKEHIPS Remix)
# 124          The Weeknd - Wanderlust (SNAKEHIPS Remix)
# 125                          SNAKEHIPS - Miss U Always
# 126                                SNAKEHIPS - Make It
# 127  SNAKEHIPS - On & On (ft George Maple) OFFICIAL...
#
#                                            description  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER.\n...
# 3    Snakehips & EARTHGANG feat Sinéad Harnett - Be...
# 4    Snakehips - Bringing Me Home (feat. LAUREL) \n...
# ..                                                 ...
# 123  »Follow Snakehips:\nSoundcloud: https://soundc...
# 124  »Follow Snakehips:\nSoundcloud: https://soundc...
# 125  »Follow Snakehips:\nSoundcloud: https://soundc...
# 126  »Follow Snakehips:\nhttps://soundcloud.com/sna...
# 127  »PREORDER LIMITED 12INCH 'ON&ON' VINYL HERE: h...
#
#                                                   tags  \
# 0    ['snakehips majestic casual snake hips hip hop...
# 1    ['snakehips majestic casual snake hips hip hop...
# 2    ['snakehips majestic casual snake hips hip hop...
# 3    ['snakehips majestic casual snake hips hip hop...
# 4    ['snakehips majestic casual snake hips hip hop...
# ..                                                 ...
# 123  ['snakehips', 'majestic casual', 'forever', 's...
# 124  ['snakehips', 'majestic casual', 'snake', 'hip...
# 125  ['snakehips', 'majestic casual', 'snake', 'hip...
# 126  ['snakehips', 'majestic casual', 'snake', 'hip...
# 127  ['snakehips', 'on and on', 'majestic', 'noisey...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-07-25 19:17:16+00:00     4983.0      212.0             NaN
# 1   2024-07-22 17:20:17+00:00     7341.0      339.0             NaN
# 2   2024-07-19 16:00:08+00:00   341304.0     2112.0             NaN
# 3   2024-06-23 08:54:29+00:00   163764.0     3121.0             NaN
# 4   2023-12-13 12:57:52+00:00   154845.0      321.0             NaN
# ..                        ...        ...        ...             ...
# 123 2014-06-18 14:46:32+00:00    15605.0      261.0             NaN
# 124 2014-06-18 11:33:18+00:00   838720.0     8766.0             NaN
# 125 2014-06-17 16:43:37+00:00    47582.0      593.0             NaN
# 126 2014-06-17 11:34:41+00:00    49497.0      462.0             NaN
# 127 2013-05-03 11:38:32+00:00   289976.0     4055.0             NaN
#
#      commentCount  ... pushblishDayName tagCount    durationSecs  \
# 0             7.0  ...         Thursday       13 0 days 00:03:18
# 1             9.0  ...           Monday       13 0 days 00:03:42
# 2            53.0  ...           Friday       13 0 days 00:02:56
# 3            32.0  ...           Sunday       21 0 days 00:03:10
# 4             7.0  ...        Wednesday       13 0 days 00:03:30
# ..            ...  ...              ...      ...             ...
# 123           4.0  ...        Wednesday       21 0 days 00:02:45
# 124          62.0  ...        Wednesday       21 0 days 00:03:41
# 125          11.0  ...          Tuesday       18 0 days 00:02:36
# 126          10.0  ...          Tuesday       18 0 days 00:03:42
# 127         173.0  ...           Friday       23 0 days 00:03:19
#
#     duration_seconds  publishedAt_timestamp        date caption_False  \
# 0              198.0           1.721935e+09  2024-07-25          True
# 1              222.0           1.721669e+09  2024-07-22          True
# 2              176.0           1.721405e+09  2024-07-19          True
# 3              190.0           1.719133e+09  2024-06-23          True
# 4              210.0           1.702472e+09  2023-12-13          True
# ..               ...                    ...         ...           ...
# 123            165.0           1.403103e+09  2014-06-18          True
# 124            221.0           1.403091e+09  2014-06-18          True
# 125            156.0           1.403023e+09  2014-06-17          True
# 126            222.0           1.403005e+09  2014-06-17          True
# 127            199.0           1.367581e+09  2013-05-03          True
#
#      caption_True  definition_hd  definition_sd
# 0           False           True          False
# 1           False           True          False
# 2           False           True          False
# 3           False           True          False
# 4           False           True          False
# ..            ...            ...            ...
# 123         False          False           True
# 124         False          False           True
# 125         False          False           True
# 126         False          False           True
# 127         False           True          False
#
# [128 rows x 21 columns]

# %% [markdown]
# ### Selecting Relevant Columns
#
# In this step, we select the most relevant columns for our machine learning tasks. This helps in focusing on the features that are most likely to impact the model's performance.

# %%
columns_to_keep = [
    'title', 'publishedAt_timestamp', 'viewCount', 'likeCount',
    'commentCount', 'tagCount', 'duration_seconds',
    'caption_False', 'caption_True', 'definition_hd', 'definition_sd', 'pushblishDayName'
]

# Keep only the relevant columns
hips = hips[columns_to_keep]

# %%
hips
# Out:
#                                                  title  publishedAt_timestamp  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...           1.721935e+09
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....           1.721669e+09
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER. (...           1.721405e+09
# 3    Snakehips & EARTHGANG (SNAKEGANG) feat Sinéad ...           1.719133e+09
# 4    Snakehips - Bringing Me Home (feat. LAUREL) (O...           1.702472e+09
# ..                                                 ...                    ...
# 123               Banks - Warm Water (SNAKEHIPS Remix)           1.403103e+09
# 124          The Weeknd - Wanderlust (SNAKEHIPS Remix)           1.403091e+09
# 125                          SNAKEHIPS - Miss U Always           1.403023e+09
# 126                                SNAKEHIPS - Make It           1.403005e+09
# 127  SNAKEHIPS - On & On (ft George Maple) OFFICIAL...           1.367581e+09
#
#      viewCount  likeCount  commentCount  tagCount  duration_seconds  \
# 0       4983.0      212.0           7.0        13             198.0
# 1       7341.0      339.0           9.0        13             222.0
# 2     341304.0     2112.0          53.0        13             176.0
# 3     163764.0     3121.0          32.0        21             190.0
# 4     154845.0      321.0           7.0        13             210.0
# ..         ...        ...           ...       ...               ...
# 123    15605.0      261.0           4.0        21             165.0
# 124   838720.0     8766.0          62.0        21             221.0
# 125    47582.0      593.0          11.0        18             156.0
# 126    49497.0      462.0          10.0        18             222.0
# 127   289976.0     4055.0         173.0        23             199.0
#
#      caption_False  caption_True  definition_hd  definition_sd  \
# 0             True         False           True          False
# 1             True         False           True          False
# 2             True         False           True          False
# 3             True         False           True          False
# 4             True         False           True          False
# ..             ...           ...            ...            ...
# 123           True         False          False           True
# 124           True         False          False           True
# 125           True         False          False           True
# 126           True         False          False           True
# 127           True         False           True          False
#
#     pushblishDayName
# 0           Thursday
# 1             Monday
# 2             Friday
# 3             Sunday
# 4          Wednesday
# ..               ...
# 123        Wednesday
# 124        Wednesday
# 125          Tuesday
# 126          Tuesday
# 127           Friday
#
# [128 rows x 12 columns]

# %% [markdown]
# Relevant Columns: We keep columns that provide useful information for analysis and modeling, such as viewCount, likeCount, commentCount, and duration_seconds.
# Boolean Columns: We include boolean columns like caption_False, caption_True, definition_hd, and definition_sd to capture categorical information in a binary format.
# Timestamp: The publishedAt_timestamp column is kept for any time-based analysis.
# This step ensures that our dataset is streamlined and contains only the most pertinent features for our machine learning tasks.

# %% [markdown]
# ### Normalizing/Standardizing Numerical Columns
#
# In this step, we normalize or standardize the numerical columns to ensure that they contribute equally to the model. This helps in improving the performance and stability of machine learning models.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Columns to normalize/standardize
columns_to_scale = ['viewCount', 'likeCount', 'commentCount', 'tagCount', 'duration_seconds']

# Initialize the scaler (choose one: StandardScaler or MinMaxScaler)
scaler = StandardScaler()  # For standardization
# scaler = MinMaxScaler()  # For normalization

# Fit and transform the data
hips[columns_to_scale] = scaler.fit_transform(hips[columns_to_scale])
# Out:
# <ipython-input-30-a0b068d507b3>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hips[columns_to_scale] = scaler.fit_transform(hips[columns_to_scale])

# %% [markdown]
# Columns to Scale: We select the columns viewCount, likeCount, commentCount, tagCount, and duration_seconds for scaling.
# Choose Scaler: We can choose between StandardScaler for standardization (mean = 0, standard deviation = 1) or MinMaxScaler for normalization (scales data to a range of [0, 1]).
# Fit and Transform: The selected columns are scaled using the chosen scaler.
# This step ensures that the numerical features are scaled appropriately, which is crucial for many machine learning algorithms.

# %%
hips
# Out:
#                                                  title  publishedAt_timestamp  \
# 0    Snakehips & EARTHGANG (SNAKEGANG) - The Remedy...           1.721935e+09
# 1    Snakehips & EARTHGANG (SNAKEGANG) - Bounce ft....           1.721669e+09
# 2    Snakehips & EARTHGANG (SNAKEGANG) - GLIMMER. (...           1.721405e+09
# 3    Snakehips & EARTHGANG (SNAKEGANG) feat Sinéad ...           1.719133e+09
# 4    Snakehips - Bringing Me Home (feat. LAUREL) (O...           1.702472e+09
# ..                                                 ...                    ...
# 123               Banks - Warm Water (SNAKEHIPS Remix)           1.403103e+09
# 124          The Weeknd - Wanderlust (SNAKEHIPS Remix)           1.403091e+09
# 125                          SNAKEHIPS - Miss U Always           1.403023e+09
# 126                                SNAKEHIPS - Make It           1.403005e+09
# 127  SNAKEHIPS - On & On (ft George Maple) OFFICIAL...           1.367581e+09
#
#      viewCount  likeCount  commentCount  tagCount  duration_seconds  \
# 0    -0.191827  -0.204335     -0.177620 -0.166104          0.026850
# 1    -0.191531  -0.202796     -0.176721 -0.166104          0.095302
# 2    -0.149533  -0.181301     -0.156944 -0.166104         -0.035897
# 3    -0.171860  -0.169069     -0.166383  1.112771          0.004033
# 4    -0.172981  -0.203014     -0.177620 -0.166104          0.061076
# ..         ...        ...           ...       ...               ...
# 123  -0.190492  -0.203741     -0.178969  1.112771         -0.067271
# 124  -0.086980  -0.100632     -0.152898  1.112771          0.092450
# 125  -0.186470  -0.199716     -0.175822  0.633193         -0.092940
# 126  -0.186230  -0.201305     -0.176272  0.633193          0.095302
# 127  -0.155988  -0.157745     -0.103006  1.432489          0.029703
#
#      caption_False  caption_True  definition_hd  definition_sd  \
# 0             True         False           True          False
# 1             True         False           True          False
# 2             True         False           True          False
# 3             True         False           True          False
# 4             True         False           True          False
# ..             ...           ...            ...            ...
# 123           True         False          False           True
# 124           True         False          False           True
# 125           True         False          False           True
# 126           True         False          False           True
# 127           True         False           True          False
#
#     pushblishDayName
# 0           Thursday
# 1             Monday
# 2             Friday
# 3             Sunday
# 4          Wednesday
# ..               ...
# 123        Wednesday
# 124        Wednesday
# 125          Tuesday
# 126          Tuesday
# 127           Friday
#
# [128 rows x 12 columns]

# %% [markdown]
# ### Correlation Matrix and Heatmap Visualization
#
# In this step, we calculate the correlation matrix for the numerical columns in our dataset and visualize it using a heatmap. This helps in understanding the relationships between different numerical features.

# %%
corr = hips.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).corr()

sns.heatmap(corr, annot=True, cmap='summer_r')
plt.show()

# %% [markdown]
# Correlation Matrix: We use the select_dtypes method to select numerical columns and then calculate their correlation matrix using the corr method. The correlation matrix shows the pairwise correlation coefficients between numerical features.
# Heatmap Visualization: We use the seaborn library to create a heatmap of the correlation matrix. The annot=True parameter adds the correlation coefficients to the heatmap, and cmap='summer_r' sets the color map to 'summer_r' for better visualization.
# This step helps in identifying the strength and direction of relationships between numerical features, which can be useful for feature selection and understanding data dependencies.
